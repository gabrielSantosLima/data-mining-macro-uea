# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import euclidean

from datetime import datetime, date

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_19756\4281365235.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('../data/dataset.csv')

# %%
sns.boxplot(x=data['nota_final'])
plt.show()

# %%
data[data['idade'] < 0]
# Out:
#        numinscricao  classificacao opcao_curso_2 opcao_3_curso  nota_final  \
# 668       6826823-8              1          6016          7016      19.929
# 1501      6415335-5            734          6016          7016      32.154
# 1739      6350899-0            972          6016          7016      28.368
# 2522      6606875-4              1          6067          7067      43.725
# 4564      6456141-0            138          6069          7069      44.106
# ...             ...            ...           ...           ...         ...
# 183509    2610665-5             62          2091          3091      38.303
# 183765    2386530-0             52          3091            No      39.046
# 183778    2610665-5             65          2091          3091      38.303
# 184082    2386530-0             87          3091            No      39.046
# 184098    2610665-5            103          2091          3091      38.303
#
#         nota_cg  nota_etapa_1  nota_ce  nota_redacao  nota_etapa_2  \
# 668      17.857        17.857      8.0         14.00        22.000
# 1501     29.762        29.762     18.0         16.55        34.545
# 1739     26.190        26.190     14.0         16.55        30.545
# 2522     36.905        36.905     34.0         16.55        50.545
# 4564     41.667        41.667     30.0         16.55        46.545
# ...         ...           ...      ...           ...           ...
# 183509   33.333        33.333     28.0         15.27        43.273
# 183765   25.000        25.000     34.0         19.09        53.091
# 183778   33.333        33.333     28.0         15.27        43.273
# 184082   25.000        25.000     34.0         19.09        53.091
# 184098   33.333        33.333     28.0         15.27        43.273
#
#         opcao_curso_1  id_referencia_curso            nome_referencia_curso  \
# 668              5016                 5016   Enfermagem - Integral - Manaus
# 1501             5016                 5016   Enfermagem - Integral - Manaus
# 1739             5016                 5016   Enfermagem - Integral - Manaus
# 2522             5067                 5067     Medicina - Integral - Manaus
# 4564             5069                 5069  Odontologia - Integral - Manaus
# ...               ...                  ...                              ...
# 183509           1091                 1091     Direito - Noturno - Manicoré
# 183765           2091                 2091     Direito - Noturno - Manicoré
# 183778           1091                 2091     Direito - Noturno - Manicoré
# 184082           2091                 3091     Direito - Noturno - Manicoré
# 184098           1091                 3091     Direito - Noturno - Manicoré
#
#          ano  idade  aprovado
# 668     2019    -37         0
# 1501    2019    -46         0
# 1739    2019    -49         0
# 2522    2019    -46         0
# 4564    2019    -49         0
# ...      ...    ...       ...
# 183509  2022    -42         0
# 183765  2022    -32         0
# 183778  2022    -42         0
# 184082  2022    -32         0
# 184098  2022    -42         0
#
# [688 rows x 16 columns]
