# %% [markdown]
# # Análise de Candidatos ao Vestibular da UEA
#
# -  Análise exploratória
#     - [X] Verificar existência de dados nulos
#     - [X] Formatar ``datanasc`` de str para datetime
#     - [X] Formatar ``classificacao`` de float para int
#     - [X] Criar atributo ``idade``
#     - [X] Formatar atributo ``id_referencia_grupo``
#     - [ ] Ordenar (na ordem que aparece na leitura do PDF) dataframe considerando:
#         1. Por ``ano``
#         2. Por ``curso_nome_referencia``
#         3. Por ``id_curso_referencia``
#         4. Por ``classificacao``
#
#
# ## Pré-processamento dos dados

# %%
import numpy as np 
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Carregando o dataset

# %%
data = pd.read_csv('./data/csv/2023_candidates_info.csv', sep=',', encoding='utf-8')

# %%
data.head(5)
# Out:
#   numinscricao                      nome  datanasc  classificacao  \
# 0    6354130-0  EDIJANE PINHEIRO MARTINS  04/03/92          313.0
# 1    6318761-2  JOEL DOS SANTOS DE SOUZA  09/03/97          314.0
# 2    6379123-4  CARINA DAS CHAGAS SEIXAS  23/10/96          315.0
# 3    6549853-4     IRLA DA SILVA PEREIRA  07/02/01          316.0
# 4    6393350-0       IVANIR LIMA PEREIRA  11/03/91          317.0
#
#   opcao_curso_2 opcao_3_curso habilidades nota_final nota_cg nota_etapa_1  \
# 0            No            No          No     31,161  19,048       19,048
# 1            No            No          No     31,154  29,762       29,762
# 2            No            No          No     31,154  29,762       29,762
# 3            No            No          No     31,113  30,952       30,952
# 4            No            No          No     31,113  30,952       30,952
#
#    disc1  disc2  disc3 nota_ce nota_redacao nota_etapa_2  opcao_curso_1  \
# 0      3      5      6   28,00        15,27       43,273           4069
# 1      3      1      4   16,00        16,55       32,545           4069
# 2      3      3      2   16,00        16,55       32,545           4069
# 3      4      0      4   16,00        15,27       31,273           4069
# 4      2      3      3   16,00        15,27       31,273           4069
#
#    id_referencia_curso            nome_referencia_curso   ano
# 0                 4069  Odontologia - Integral - Manaus  2019
# 1                 4069  Odontologia - Integral - Manaus  2019
# 2                 4069  Odontologia - Integral - Manaus  2019
# 3                 4069  Odontologia - Integral - Manaus  2019
# 4                 4069  Odontologia - Integral - Manaus  2019

# %% [markdown]
# ## Análise exploratória dos dados

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184389 entries, 0 to 184388
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   numinscricao           184389 non-null  object
#  1   nome                   184389 non-null  object
#  2   datanasc               184389 non-null  object
#  3   classificacao          184389 non-null  float64
#  4   opcao_curso_2          184389 non-null  object
#  5   opcao_3_curso          184389 non-null  object
#  6   habilidades            184389 non-null  object
#  7   nota_final             184389 non-null  object
#  8   nota_cg                184389 non-null  object
#  9   nota_etapa_1           184389 non-null  object
#  10  disc1                  184389 non-null  int64
#  11  disc2                  184389 non-null  int64
#  12  disc3                  184389 non-null  int64
#  13  nota_ce                184389 non-null  object
#  14  nota_redacao           184389 non-null  object
#  15  nota_etapa_2           184389 non-null  object
#  16  opcao_curso_1          184389 non-null  int64
#  17  id_referencia_curso    184389 non-null  int64
#  18  nome_referencia_curso  184389 non-null  object
#  19  ano                    184389 non-null  int64
# dtypes: float64(1), int64(6), object(13)
# memory usage: 28.1+ MB

# %% [markdown]
# #### Verificando a existência de colunas com dados nulos

# %%
data.isnull().sum()
# Out:
# numinscricao             0
# nome                     0
# datanasc                 0
# classificacao            0
# opcao_curso_2            0
# opcao_3_curso            0
# habilidades              0
# nota_final               0
# nota_cg                  0
# nota_etapa_1             0
# disc1                    0
# disc2                    0
# disc3                    0
# nota_ce                  0
# nota_redacao             0
# nota_etapa_2             0
# opcao_curso_1            0
# id_referencia_curso      0
# nome_referencia_curso    0
# ano                      0
# dtype: int64

# %% [markdown]
# #### Formatando coluna 'datanasc' para o formato date

# %%
data.sample(2)
# Out:
#      numinscricao                          nome  datanasc  classificacao  \
# 5239    5261271-6         EIDRA DA GAMA ALENCAR  24/09/89             21
# 4184    5158308-9  PEDRO ANAEL BARBOSA DA SILVA  11/09/05             82
#
#      opcao_curso_2 opcao_3_curso habilidades nota_final nota_cg nota_etapa_1  \
# 5239          2045          3045          No     35,766  35,714       35,714
# 4184          2025          3025          No     36,939  33,333       33,333
#
#       disc1  disc2  disc3  nota_ce nota_redacao nota_etapa_2  opcao_curso_1  \
# 5239      4      3      2       18        17,82       35,818           1045
# 4184      5      4      3       24        16,55       40,545           1025
#
#       id_referencia_curso                              nome_referencia_curso  \
# 5239                 1045  Licenciatura em Letras - Língua Portuguesa - M...
# 4184                 1025            Engenharia Mecânica - Integral - Manaus
#
#        ano
# 5239  2023
# 4184  2023

# %% [markdown]
# ## Criando novos atributos

# %%
def adjuste_year(year):
    if year <= 24:
        return 2000 + year
    else:
        return 1900 + year

def calculate_age(row):
    data_str = row['datanasc']
    current_year = row['ano']
    
    data = datetime.strptime(data_str, '%d/%m/%y')
    born_year = adjuste_year(data.year % 100)
    idade = current_year - born_year
    
    return idade

data['idade'] = data.apply(calculate_age, axis=1)

# %%
data[data['idade'] < 0]
# Out:
# Empty DataFrame
# Columns: [numinscricao, nome, datanasc, classificacao, opcao_curso_2, opcao_3_curso, habilidades, nota_final, nota_cg, nota_etapa_1, disc1, disc2, disc3, nota_ce, nota_redacao, nota_etapa_2, opcao_curso_1, id_referencia_curso, nome_referencia_curso, ano, idade]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.sample(2)
# Out:
#       numinscricao                          nome  datanasc  classificacao  \
# 6641     4959103-7    ELIAS EDSON ALVES DA SILVA  09/11/05            175
# 35878    4893545-0  WALCLERC MACEDO ALVES JUNIOR  19/08/04            594
#
#       opcao_curso_2 opcao_3_curso habilidades nota_final nota_cg nota_etapa_1  \
# 6641           2066          3066          No     37,403  35,714       35,714
# 35878            No            No          No     42,635  36,905       36,905
#
#        ...  disc2  disc3  nota_ce  nota_redacao nota_etapa_2 opcao_curso_1  \
# 6641   ...      2      3       20         19,09       39,091          1066
# 35878  ...      2      5       28         20,36       48,364          4063
#
#        id_referencia_curso                       nome_referencia_curso   ano  \
# 6641                  1066  Sistemas de Informação - Integral - Manaus  2023
# 35878                 4063                Medicina - Integral - Manaus  2023
#
#        idade
# 6641      18
# 35878     19
#
# [2 rows x 21 columns]

# %% [markdown]
# #### Padronizando as colunas referentes a opção de curso

# %%
data['opcao_curso_1'] = data['opcao_curso_1'].astype(str)
data['id_referencia_curso'] = data['id_referencia_curso'].astype(str)

# %%
data['opcao_3_curso'] = data['opcao_3_curso'].apply(lambda x: x[1:] if str(x).startswith('0') else x)
data['opcao_curso_2'] = data['opcao_curso_2'].apply(lambda x: x[1:] if str(x).startswith('0') else x)

# %%
data.head(8)
# Out:
#   numinscricao                                          nome  datanasc  \
# 0    5272408-5                  LEANDRO VITOR DE SOUZA PRAIA  15/11/06
# 1    4873733-0                YANA KATRINE PEDROSO ESPINDULA  26/07/01
# 2    5014911-3                  ELBER LUCAS VIEIRA RODRIGUES  17/09/05
# 3    4931578-1                 ANA LIZ ASAEL FREITAS RIBEIRO  17/07/05
# 4    4949027-3  ALVARO FRANCISCO PIMENTEL DE OLIVEIRA JUNIOR  17/04/04
# 5    5241586-4              LOHANNE DE SOUZA RANGEL BAPTISTA  10/01/06
# 6    4994885-7                             ELISA BRITO OMENA  24/01/06
# 7    4925609-2                         JHULIANO MAIA SARAIVA  12/07/05
#
#    classificacao opcao_curso_2 opcao_3_curso habilidades nota_final nota_cg  \
# 0              1          2001          3001          No     66,639  63,095
# 1              2          2001          3001          No     59,818      50
# 2              3          2001          3001          No     59,199  54,762
# 3              4          2001          3001          No     58,091      50
# 4              5          2001          3001          No     57,712  58,333
# 5              6          2001          3001          No     56,413   51,19
# 6              7          2001          3001          No     56,373  52,381
# 7              8          2001          3001          No     56,199  54,762
#
#   nota_etapa_1  ...  disc2  disc3  nota_ce  nota_redacao nota_etapa_2  \
# 0       63,095  ...      4     11       46         24,18       70,182
# 1           50  ...      7      7       48         21,64       69,636
# 2       54,762  ...      5      9       42         21,64       63,636
# 3           50  ...      6      8       42         24,18       66,182
# 4       58,333  ...      3      9       38         19,09       57,091
# 5        51,19  ...      4      8       40         21,64       61,636
# 6       52,381  ...      7      6       40         20,36       60,364
# 7       54,762  ...      4      8       36         21,64       57,636
#
#   opcao_curso_1 id_referencia_curso             nome_referencia_curso   ano  \
# 0          1001                1001  Administração - Noturno - Manaus  2023
# 1          1001                1001  Administração - Noturno - Manaus  2023
# 2          1001                1001  Administração - Noturno - Manaus  2023
# 3          1001                1001  Administração - Noturno - Manaus  2023
# 4          1001                1001  Administração - Noturno - Manaus  2023
# 5          1001                1001  Administração - Noturno - Manaus  2023
# 6          1001                1001  Administração - Noturno - Manaus  2023
# 7          1001                1001  Administração - Noturno - Manaus  2023
#
#    idade
# 0     17
# 1     22
# 2     18
# 3     18
# 4     19
# 5     17
# 6     17
# 7     18
#
# [8 rows x 21 columns]

# %%
data.dtypes
# Out:
# numinscricao             object
# nome                     object
# datanasc                 object
# classificacao             int64
# opcao_curso_2            object
# opcao_3_curso            object
# habilidades              object
# nota_final               object
# nota_cg                  object
# nota_etapa_1             object
# disc1                     int64
# disc2                     int64
# disc3                     int64
# nota_ce                   int64
# nota_redacao             object
# nota_etapa_2             object
# opcao_curso_1            object
# id_referencia_curso      object
# nome_referencia_curso    object
# ano                       int64
# idade                     int64
# dtype: object

# %%
year_dataframes = {}
for year in data["ano"].unique():
    df_year = data.loc[data["ano"] == year]
    year_dataframes[year] = df_year

# %%
ordered_classifications = {}

for year, df_year in year_dataframes.items():
    year_info = {}
    for course_id in df_year['id_referencia_curso'].unique():
        df_course_year = df_year.loc[df_year['id_referencia_curso'] == course_id]
        df_course_year = df_course_year.sort_values("classificacao")
        year_info[course_id] = df_course_year
    ordered_classifications[year] = year_info

# %%
del year_info

# %%
dataframes_year = []

for ano, id_group in ordered_classifications.items():
    for id in id_group:
      df_year = pd.DataFrame.from_dict(id_group[id])
      dataframes_year.append(df_year)
full_df = pd.concat(dataframes_year, ignore_index=True)
# full_df.to_csv("../data/csv/lista_classificacao_vestibular_completo.csv", index=False)

# %%
del id, id_group, df_year

# %%
dados_vaga = pd.read_csv('./data/csv/2023_approved_candidates.csv', sep=',', encoding='utf-8')

# %%
full_df['aprovado'] = full_df['nome'].isin(dados_vaga['nome'].values).astype(int)

# %%
years_full_df = full_df['ano'].unique()
years_dados_vaga = dados_vaga['ano'].unique()

for year in years_full_df:
    if year in years_dados_vaga:
        full_df_year = full_df[full_df['ano'] == year]
        dados_vaga_year = dados_vaga[dados_vaga['ano'] == year]

        full_df.loc[full_df_year.index, 'aprovado'] = full_df_year['nome'].isin(dados_vaga_year['nome'].values).astype(int)
        full_df['aprovado'] = full_df['aprovado'].astype(int)

# %%
def prefix(row):
  prefixo = row[0]
  return 1 if prefixo in ['1', '5'] else 0

full_df['egresso_publica'] = full_df['opcao_curso_1'].apply(prefix)

# %% [markdown]
# ## Formatando Dataset para treino

# %%
columns = ['nota_final', 'nota_ce', 'nota_cg', 'nota_etapa_1', 'nota_etapa_2', 'nota_redacao']

for column in columns:
    full_df[column] = full_df[column].astype(str).str.replace(',', '.').astype(float)

# %%
full_df.sample(2)
# Out:
#       numinscricao                                 nome  datanasc  \
# 47101    4883941-8  YASMIN GABRIELLA FERNANDES FERREIRA  08/05/04
# 32019    4873968-5               JUAN DA SILVA FIGUEIRA  01/12/01
#
#        classificacao opcao_curso_2 opcao_3_curso habilidades  nota_final  \
# 47101            945          7063            No          No      67.002
# 32019             26          2104          3104          No      33.957
#
#        nota_cg  nota_etapa_1  ...  nota_ce  nota_redacao  nota_etapa_2  \
# 47101   63.095        63.095  ...     48.0         22.91        70.909
# 32019   38.095        38.095  ...     12.0         17.82        29.818
#
#        opcao_curso_1  id_referencia_curso  \
# 47101           6063                 7063
# 32019           1104                 3104
#
#                                   nome_referencia_curso   ano idade aprovado  \
# 47101                      Medicina - Integral - Manaus  2023    19        0
# 32019  Licenciatura em Geografia - Matutino - Parintins  2023    22        1
#
#        egresso_publica
# 47101                0
# 32019                1
#
# [2 rows x 23 columns]

# %%
full_df
# Out:
#       numinscricao                                          nome  datanasc  \
# 0        5272408-5                  LEANDRO VITOR DE SOUZA PRAIA  15/11/06
# 1        4873733-0                YANA KATRINE PEDROSO ESPINDULA  26/07/01
# 2        5014911-3                  ELBER LUCAS VIEIRA RODRIGUES  17/09/05
# 3        4931578-1                 ANA LIZ ASAEL FREITAS RIBEIRO  17/07/05
# 4        4949027-3  ALVARO FRANCISCO PIMENTEL DE OLIVEIRA JUNIOR  17/04/04
# ...            ...                                           ...       ...
# 52082    4977888-9                       ELZIARA CONCEICAO RAMOS  25/02/00
# 52083    4962753-8                       MANOEL CARVALHO MACARIO  03/09/95
# 52084    5008913-7                  JOAO FELIPE NOGUEIRA DE DEUS  23/10/00
# 52085    4944854-4                     LUIZ DOUGLAS GAMA MARQUES  06/11/94
# 52086    4953452-1                         KEITH LOPES GONCALVES  14/03/06
#
#        classificacao opcao_curso_2 opcao_3_curso habilidades  nota_final  \
# 0                  1          2001          3001          No      66.639
# 1                  2          2001          3001          No      59.818
# 2                  3          2001          3001          No      59.199
# 3                  4          2001          3001          No      58.091
# 4                  5          2001          3001          No      57.712
# ...              ...           ...           ...         ...         ...
# 52082              1            No            No          No      44.165
# 52083              1            No            No          No      31.004
# 52084              1            No            No          No      41.593
# 52085              1            No            No          No      45.165
# 52086              1            No            No          No      35.063
#
#        nota_cg  nota_etapa_1  ...  nota_ce  nota_redacao  nota_etapa_2  \
# 0       63.095        63.095  ...     46.0         24.18        70.182
# 1       50.000        50.000  ...     48.0         21.64        69.636
# 2       54.762        54.762  ...     42.0         21.64        63.636
# 3       50.000        50.000  ...     42.0         24.18        66.182
# 4       58.333        58.333  ...     38.0         19.09        57.091
# ...        ...           ...  ...      ...           ...           ...
# 52082   45.238        45.238  ...     24.0         19.09        43.091
# 52083   26.190        26.190  ...     18.0         17.82        35.818
# 52084   38.095        38.095  ...     26.0         19.09        45.091
# 52085   45.238        45.238  ...     26.0         19.09        45.091
# 52086   29.762        29.762  ...     20.0         20.36        40.364
#
#        opcao_curso_1  id_referencia_curso  \
# 0               1001                 1001
# 1               1001                 1001
# 2               1001                 1001
# 3               1001                 1001
# 4               1001                 1001
# ...              ...                  ...
# 52082           9139                 9139
# 52083           9140                 9140
# 52084           9144                 9144
# 52085           9145                 9145
# 52086           9152                 9152
#
#                                    nome_referencia_curso   ano idade aprovado  \
# 0                       Administração - Noturno - Manaus  2023    17        1
# 1                       Administração - Noturno - Manaus  2023    22        1
# 2                       Administração - Noturno - Manaus  2023    18        1
# 3                       Administração - Noturno - Manaus  2023    18        1
# 4                       Administração - Noturno - Manaus  2023    19        1
# ...                                                  ...   ...   ...      ...
# 52082  Tecnologia em Gestão Hospitalar - Matutino - P...  2023    23        1
# 52083        Licenciatura em Geografia - Noturno - Santo  2023    28        1
# 52084  Tecnologia em Gestão Hospitalar - Matutino - Tefé  2023    23        1
# 52085  Licenciatura em Matemática - Noturno - Urucuri...  2023    29        1
# 52086  Tecnologia em Gestão Hospitalar - Matutino - P...  2023    17        1
#
#        egresso_publica
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 52082                0
# 52083                0
# 52084                0
# 52085                0
# 52086                0
#
# [52087 rows x 23 columns]

# %%
full_df.drop(columns=['nome', 'disc1', 'disc2', 'disc3', 'habilidades', 'datanasc'], inplace=True)

# %%
full_df.to_csv('./data/2023_dataset.csv', index=False)
